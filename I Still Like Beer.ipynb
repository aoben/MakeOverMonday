# %%
import pandas as pd
import numpy as np

# %%
i_still_like_beer = pd.read_excel('./MLB Beer Prices.xlsx')

# %%
i_still_like_beer.head()
# Out:
#    Year                  Team      Nickname       City  Price  Size  \
# 0  2013  Arizona Diamondbacks  Diamondbacks    Arizona   4.00  14.0
# 1  2013        Atlanta Braves        Braves    Atlanta   7.25  16.0
# 2  2013     Baltimore Orioles       Orioles  Baltimore   6.75  18.0
# 3  2013        Boston Red Sox       Red Sox     Boston   7.25  12.0
# 4  2013          Chicago Cubs          Cubs    Chicago   7.25  16.0
#
#    Price per Ounce
# 0         0.285714
# 1         0.453125
# 2         0.375000
# 3         0.604167
# 4         0.453125

# %%
i_still_like_beer.shape
# Out:
# (155, 7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
i_still_like_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 7 columns):
# Year               155 non-null int64
# Team               155 non-null object
# Nickname           155 non-null object
# City               150 non-null object
# Price              155 non-null float64
# Size               155 non-null float64
# Price per Ounce    155 non-null float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 8.6+ KB

# %%
i_still_like_beer.isnull().any()
# Out:
# Year               False
# Team               False
# Nickname           False
# City                True
# Price              False
# Size               False
# Price per Ounce    False
# dtype: bool

# %%
sns.distplot(i_still_like_beer['Size'])

# %%
sns.distplot(i_still_like_beer['Price'])

# %%
sns.distplot(i_still_like_beer['Price per Ounce'])

# %%
sns.set()

# %%
plt.figure(figsize=(16,10))  #configure the size of the plot

sns.barplot(x='Price', y='City', data=i_still_like_beer, palette="Blues_d")

# %%
plt.figure(figsize=(16,10))
sns.barplot(x='Size', y='City', data=i_still_like_beer, palette="Reds")

# %%
sns.lineplot(x='Size', y='Price', data=i_still_like_beer)

# %%
sns.scatterplot(x='Size', y='Price', data=i_still_like_beer)
